# %%
from PIL import Image
import io #The io module provides Python’s main facilities for dealing with various types of I/O 
import pathlib #This module offers classes representing filesystem paths with semantics appropriate for different operating systems

im = Image.open('input.png')

im2 = Image.open(pathlib.Path('input.png'))

f = open('input.png', 'rb')
im3 = Image.open(f)

with open('input.png', 'rb') as f:
    im4 = Image.open(io.BytesIO(f.read()))

# Dangerous FAIL:
with open('input.png', 'rb') as f:
    im5 = Image.open(f)
im5.load() # FAILS, closed file
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-8294cdf10f82> in <module>()
#      16 with open('input.png', 'rb') as f:
#      17     im5 = Image.open(f)
# ---> 18 im5.load() # FAILS, closed file
#
# /usr/local/lib/python3.7/dist-packages/PIL/ImageFile.py in load(self)
#     224                 )
#     225                 try:
# --> 226                     seek(offset)
#     227                     decoder.setimage(self.im, extents)
#     228                     if decoder.pulls_fd:
#
# ValueError: seek of closed file
